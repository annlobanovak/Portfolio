# %% [markdown]
# ### Описание Портфолио
# В данном репозитории опубликованы проекты, которые я выполнила, обучаясь в Skillfactory на курсе "Профессия Аналитик Данных"
#
# 1. **Основа рекомендательной системы для онлайн-школы**
#
# -Кейс: Для увеличения продаж и среднего чека онлайн-школа запускает систему рекомендаций, которые получают пользователи при оформлении корзины.
#
# -Задача: На основе анализа базы данных о продажах за предыдущие года сформировать основу рекомендательной системы, т.е. выявить наилучшие варианты рекомендаций для каждого курса.
#
# -Результат: С помощью SQL я проанализировала имеющиеся данные в БД, выгрузила необходимые в VSC и обработала с помощью Python (pandas,numpy). Составила таблицу рекомендаций готовую для внедрения на сайт
#
# (https://github.com/annlobanovak/Portfolio/blob/main/Python%2CSQL%20%D0%9E%D1%81%D0%BD%D0%BE%D0%B2%D0%B0%20%D1%80%D0%B5%D0%BA%D0%BE%D0%BC%D0%B5%D0%BD%D0%B4%D0%B0%D1%82%D0%B5%D0%BB%D1%8C%D0%BD%D0%BE%D0%B9%20%D1%81%D0%B8%D1%81%D1%82%D0%B5%D0%BC%D1%8B%20%D0%B4%D0%BB%D1%8F%20%D0%BE%D0%BD%D0%BB%D0%B0%D0%B9%D0%BD-%D1%88%D0%BA%D0%BE%D0%BB%D1%8B.ipynb)
#
#
# 2. **Анализ поведения пользователей онлайн игры**
#
# -Кейс: В приложении онлайн игры QuizFreeze запущено обновление. Разработчики хотят проверить несколько гипотез о поведении игроков после обновления.
#
# -Задача: На основе данных по поведении игроков проверить гипотезы о зависимости обучения и скорости прохождения этапов игры, дальнейших покупках. Оценить ясность взаимодействия с игрой.
#
# -Результат: С помощью Python (pandas,matplotlib) я проверила все гипотезы. Выявила прямую зависимость обучения и увеличения прибыли. Визуализировала результаты, дала рекомендации.
#
# https://github.com/annlobanovak/Portfolio/blob/main/Python%20%D0%9F%D0%BE%D0%B2%D0%B5%D0%B4%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BF%D0%BE%D0%BB%D1%8C%D0%B7%D0%BE%D0%B2%D0%B0%D1%82%D0%B5%D0%BB%D0%B5%D0%B9%20%D0%BE%D0%BD%D0%BB%D0%B0%D0%B9%D0%BD%20%D0%B8%D0%B3%D1%80%D1%8B.ipynb
#
#
# 3. **Анализ деятельности компании**
#
# -Кейс:  Pens and Pencils -  компания специализирующаяся на B2B и B2C-продажах офисных товаров.
#
# -Задача: Проанализировать работу компании с точки зрения ее эффективности и дать рекомендации по масштабированию бизнеса, а именно в каком штате лучше открыть офлайн-магазин.
#
# -Результат: Я провела анализ имеющийся БД с помощью SQL. Создала ряд визуализаций для показателей деятельности компании: эффективность продаж, портрет клиента, логистика. Сформулировала выводы по всем изученных направлениям, дала рекомендации по масштабированию бизнеса.
#
# (https://docs.google.com/document/d/1cZsJdhEAdnApu_3akbQkmm7aa5AtttrVt0KORMQM2HE/edit?usp=sharing)
#
#
# 2. **Анализ бизнес модели онлайн магазина**
#
# -Кейс:  Новосибирская компания специализирующаяся на онлайн продаже экотоваров планирует расширение бизнеса в другие регионы
#
# -Задача: Проанализировать дейятельность компании, эффективность бизнес модели, дать прогнозы и рекомендации по масштабированию бизнеса.
#
# -Результат: Я провела маркетинговый и продуктовый анализ бизнеса. Используя когортный анализ и показатели юнит-экономики, сформулировала основные выводы о рентабельности, определила основные источники привлечения и самые успешные регионы. Дала рекомендации по расширению в другие регионы. Работа реализована и визуализирована в GoogleSheets.
#
# (https://docs.google.com/spreadsheets/d/1zWaxz2-V3OD9aQkh-2aACZccyr7EXFmiIMPFN0QHP6c/edit?usp=sharing)
